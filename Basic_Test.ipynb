# %% [markdown]
# <a href="https://colab.research.google.com/github/NgocPhungggg/CUT/blob/Elements_of_Artificial_Intelligence/Basic_Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World! I am Thi Ngoc Phung Cao, a exchange student in Cracow University of Technology!")
# Out:
# Hello World! I am Thi Ngoc Phung Cao, a exchange student in Cracow University of Technology!
